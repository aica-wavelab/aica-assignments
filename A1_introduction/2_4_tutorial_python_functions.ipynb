# %%
# Full name
NAME = ""
# Institutional email (hm.edu or hmtm.de)
EMAIL = ""

# %% [markdown]
# <a href="https://colab.research.google.com/github/aica-wavelab/aica-assignments/blob/main/A1_introduction/2_4_tutorial_python_functions.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
#@title install required packages, download test files, initialize Otter

# install packages
# %pip install otter-grader==5.5.0

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/aica-wavelab/aica-assignments/contents/A1_introduction/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook(colab=True)
else:
    import otter
    grader = otter.Notebook('2_4_tutorial_python_functions.ipynb')

# %% [markdown]
# # Rudiments of Python: Functions
#
# + **AI in Culture and Arts - Tech Crash Course**
# + **Date:** 22.04.2026
# + **Authors:** [Dr. Benedikt Zönnchen](https://bzoennchen.github.io/Pages/) & [Dr. Téo Sanchez](https://teo-sanchez.github.io/)

# %% [markdown]
# ⛳ **By the end of this notebook you will be able to:**
# - Define your own Python functions using `def`
# - Write functions with parameters, return values, type hints, and docstrings
# - Test your functions with `assert` statements

# %% [markdown]
# **⚠️ Before you start — important notes for Google Colab:**
# - **Save your work first:** Go to *File → Save a copy in Drive* to save this notebook to your Google Drive. After that, Colab will auto-save your progress. You can also download your work at any time via *File → Download → Download .ipynb*❗
# - **Run cells in order, from top to bottom.** Each cell can only use variables defined in cells that have already been run❗
# - **Got an unexpected error?** Go to *Runtime → Restart session and run all* to start fresh❗
# - **Colab disconnects after ~30 minutes of inactivity**, which erases all your variables. If this happens, go to *Runtime → Restart session and run all*. Your saved notebook in Drive is not affected❗

# %% [markdown]
# ## 7 Functions
#
# In `Python`, you can define a function to execute a block of code. A function encapsulates a fragment of code into a variable that can be called multiple times.
#
# You can define a function by using the `def` keyword followed by the function name and its parameters, also called arguments. The function name must follow the same rules as variable names.
#
# ```python
# def my_function(parameter_1, parameter_2, ...):
#     # code to execute
#     return value
# ```
#
# Let's see an example of a function that returns the sum of two numbers.

# %%
def add(x, y):
    return x + y

# %% [markdown]
# After defining a function, you can call it by using its name and passing arguments.

# %%
add(4, 3)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ---
#
# 🖍 **Exercise 7.1:** What is the type of the function's arguments? What is the type returned by the function?
#
# ---

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# Types can be optionally specified in Python, but it is a good practice to do so. You can specify the type of the arguments and the return value by using the `->` operator.
#
# Using the example above, the header would become:
#
# ```python
# def add(x: int, y: int) -> int:
#     # code to execute
#     return value
# ```

# %% [markdown]
# It is also a good practice to document your function by using a docstring. A docstring is a string that describes what the function does. It is placed between triple quotes `"""`.
#
# ```python
# def add(x: int, y: int) -> int:
#     """
#     This function returns the sum of two integers.
#
#     Parameters:
#         x (int): the first integer
#         y (int): the second integer
#
#     Returns:
#         int: the sum of x and y
#     """
#     # code to execute
#     return value
# ```

# %% [markdown]
# ---
#
# 🖍 **Exercise 7.2:** Create a function named ``find_name_index`` using the docstring above.
#
# ---
#
# ```python
# """
# This function takes a list of names and a name as arguments and returns the index of the name in the list if it is found, otherwise it returns -1.
#
# Parameters:
#     names (list): a list of names
#     name (str): the name to find in the list
#
# Returns:
#     int: the index of the name in the list if it is found, otherwise -1
# """
# ```

# %%
def find_name_index(names : list, name : str) -> int:
    ...

# %%
names = ['Bene', 'Ursula', 'Maria', 'Tom']
find_name_index(names, "Ursula")

# %%
grader.check("q72")

# %% [markdown]
# `assert` is a useful keyword to test functions. It raises an `AssertionError` if the condition is `False`, and nothing if the condition is `True`.
#
# Your fonction `find_name_index` should not raise any `AssertionError` with the following tests.

# %%
names = [
    "Alice", "Bob", "Charlie", "David", "Eve", "Frank", 
    "Grace", "Helen", "Isaac", "Jane", "Karl", "Linda", 
    "Mary", "Nathan", "Olivia", "Peter", "Quinn", "Rachel", 
    "Steve", "Tom", "Ursula", "Victor", "Wendy", "Xavier", "Yvonne", "Zach"
]

assert find_name_index(names, "Alice") == 0
assert find_name_index(names, "Bob") == 1

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ---
#
# 🖍 **Exercise 7.3:** Write two extra tests that your function should pass.
#
# ---

# %%
...

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Application: british artists and songs
#
# In this section, you will create functions to manipulate a dictionary of artists and their songs.
# The questions will help you to recall the notions seen above.
#
# Let's start by creating a non-exhaustive dictionary of british artists and their songs.

# %%
brit_artists = {
    "The Beatles": [
        "Yesterday",
        "Hey Jude",
        "Let it be",
        "Come Together"
    ],
    "Queen": [
        "Bohemian Rhapsody",
        "We Will Rock You",
        "We Are The Champions",
        "Another One Bites The Dust"
    ],
    "Elton John": [
        "Rocket man",
        "Your Song",
        "Tiny Dancer",
        "Crocodile Rock"
    ],
    "David Bowie" : [
        "Space Oddity",
        "Life on Mars",
        "Heroes",
        "Starman"],
    "The Rolling Stones" : [
        "Paint it Black",
        "Sympathy for the Devil",
        "Gimme Shelter",
        "Angie"
    ]}

# %%
brit_artists["The Beatles"][0]

# %% [markdown]
# The variable `brit_artists` is a dictionary (`dict`) whose keys are strings (`str`) and values are lists (`list`) or strings.

# %% [markdown]
# ---
#
# 🖍 **Exercise 7.4:** Implement a function named `get_songs` that takes a dictionary of artists and the name of an artist as arguments and returns the list of songs of the artist if it is found, otherwise it raises a `ValueError`.
#
# ---

# %%
def get_songs(data: dict, artist_name: str) -> list:
    """ Get the list of songs from a given artist

    Args:
        data (dict): Dictionary with artists as keys and songs as values
        artist_name (str): Name of the artist

    Raises:
        ValueError: If the artist is not found in the dictionary

    Returns:
        list: List of songs from the artist
    """
    if artist_name in data:
        ...
    else:
        raise ValueError("Artist not found")

# %%
grader.check("q74")

# %% [markdown]
# ---
#
# 🖍 **Exercise 7.5:** Implement a function named `get_artist` that takes a dictionary of artists and the name of a song as arguments and returns the artist that composed the song if it is found, otherwise it raises a `ValueError`.
#
# Do not forget to indicate the types of the arguments and the return value in the function's header, as well as to write a docstring.
#
# ---

# %%
...

# %%
grader.check("q75")

# %% [markdown]
# ## Well done!
#
# You've learned the basics of `Python`, a powerful programming language that is widely used in data science and machine learning.
#
# In particular, you should now be able to:
#
#  - Identify the main basic data types in `Python`
#  - Use basic operators for numbers (`int`, `float`), strings (`str`), and booleans (`bool`)
#  - Assign values to variables using the `=` operator
#  - Create conditional structures using `if`, `elif`, and `else`
#  - Use lists (`list`) and dictionaries (`dict`) to store multiple values
#  - Use `for` and `while` loops to execute a block of code multiple times or iterate over a sequence of values
#  - Define and document functions to encapsulate a fragment of code that can be called later.
#
# It is time to learn about data science! Go to
#
# <a href="https://colab.research.google.com/github/aica-wavelab/aica-assignments/blob/main/A1_introduction/3_tutorial_data_science.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
